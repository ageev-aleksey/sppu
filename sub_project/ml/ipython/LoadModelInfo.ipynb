# %%
import sys
import os
sys.path.append(os.getcwd() + "\\..\\")

# %%
import model
import neural
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import pandas as pd
import json
import multiprocessing
import utils
# %matplotlib inline

# %%
df = utils.load_info_all_models("../models2")
# Out:
# ['nunits', '128']
# ['nblocks', '1']
# ['blockSize', '2']
# ['relu']
# -- ../models2\resnet_nunits.128_nblocks.1_blockSize.2_relu
# ['epoch', '1']
# ['epoch', '2']
# ['epoch', '4']
# ['epoch', '5']
# ['epoch', '6']
# ['epoch', '7']
# ['epoch', '8']
# ---- ../models2\resnet_nunits.128_nblocks.1_blockSize.2_relu\history.json
# {'epoch': 1}
# {'epoch': 2}
# {'epoch': 4}
# {'epoch': 5}
# {'epoch': 6}
# {'epoch': 7}
# {'epoch': 8}
# ['nunits', '128']
# ['nblocks', '1']
# ['blockSize', '3']
# ['relu']
# -- ../models2\resnet_nunits.128_nblocks.1_blockSize.3_relu
# ['epoch', '1']
# ['epoch', '10']
# ['epoch', '2']
# ['epoch', '4']
# ['epoch', '5']
# ['epoch', '6']
# ['epoch', '8']
# ---- ../models2\resnet_nunits.128_nblocks.1_blockSize.3_relu\history.json
# {'epoch': 1}
# {'epoch': 10}
# {'epoch': 2}
# {'epoch': 4}
# {'epoch': 5}
# {'epoch': 6}
# {'epoch': 8}
# ['nunits', '128']
# ['nblocks', '1']
# ['blockSize', '4']
# ['relu']
# -- ../models2\resnet_nunits.128_nblocks.1_blockSize.4_relu
# ...

# %%
next(os.walk(df.sort_values("val_loss").iloc[0]["path"]))
# Out:
# ('../models2\\resnet_nunits.16_nblocks.4_blockSize.3_relu',
#  [],
#  ['epoch.1',
#   'epoch.2',
#   'epoch.3',
#   'epoch.4',
#   'epoch.5',
#   'epoch.8',
#   'epoch.9',
#   'history.json'])
